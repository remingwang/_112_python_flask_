# %%
import requests
url = 'https://data.ntpc.gov.tw/api/datasets/71cd1490-a2df-4198-bef1-318479775e8a/csv?size=100'

response = requests.get(url)
if response.ok:
    print(response.text)

# %%
from io import StringIO
import csv
file = StringIO(response.text,newline = '')
csv_reader = csv.DictReader(file)
csv_list = list(csv_reader)
for item_dict in csv_list:
    print(item_dict)

# %%
import pandas as pd
df = pd.DataFrame(data=csv_list)
df1 = df.drop(columns=['sareaen','snaen','aren','lat','lng'])
df2 = df1.rename(columns={'\ufeff"sno"':"編號",
                    'sna':'名稱',
                    'tot':'車輛數',
                    'sbi':'可借',
                    'sarea':'行政區',
                    'mday':'日期',
                    'ar':'地址',
                    'bemp':'可還',
                    'act':'狀態'})

# %%
df2
# Out:
#       編號            名稱 車輛數  可借  行政區              日期
# 0   1001          大鵬華城  12   6  新店區  20230520152437  \
# 1   1002         汐止火車站  24  13  汐止區  20230520152432
# 2   1003         汐止區公所  24  15  汐止區  20230520152422
# 3   1004        國泰綜合醫院  28  13  汐止區  20230520152433
# 4   1006  捷運大坪林站(5號出口)  26   7  新店區  20230520152441
# ..   ...           ...  ..  ..  ...             ...
# 95  1100          音樂公園  28   0  板橋區  20230520152318
# 96  1101   捷運七張站(1號出口)  14  11  新店區  20230520152421
# 97  1102          北新國小  22   3  新店區  20230520152436
# 98  1103   捷運新埔站(2號出口)  22   3  板橋區  20230520152442
# 99  1104      聯合醫院板橋院區  20   3  板橋區  20230520152419
#
#                                  地址  可還 狀態
# 0                   新北市新店區中正路700巷3號   6  1
# 1                    南昌街/新昌路口(西側廣場)   9  1
# 2   新台五路一段/仁愛路口(新台五路側汐止地政事務所前機車停車場)   9  1
# 3                       建成路78號對面停車場  10  1
# 4                     中興路三段224號(對面)  17  1
# ..                              ...  .. ..
# 95                    大同街97號對面公園人行道  27  1
# 96                  北新路二段/北新路二段121巷   3  1
# 97                        寶橋路8號前人行道  19  1
# 98                     文化路一段318號旁廣場  18  1
# 99              龍泉街131號旁人行道(立體停車場前)  17  1
#
# [100 rows x 9 columns]
